# %%
#!pip install pandas
#!pip install selenium

# %%
#importações

import pandas as pd

# %%
#lendo arquivo
produtos = pd.read_csv('produtos.csv', delimiter=';')

produtos.head()
# Out:
#   Código do Produto                    Descrição  Preço de Compra  \
# 0           PROD001    Caneta Esferográfica Azul              0.5
# 1           PROD002  Caderno Universitário 96fls              8.0
# 2           PROD003               Lápis Preto HB              0.3
# 3           PROD004              Borracha Branca              0.4
# 4           PROD005       Apontador com Depósito              1.5
#
#    Quantidade em Estoque  Preço de Venda
# 0                    150            1.20
# 1                     75           15.00
# 2                    200            0.80
# 3                    180            0.95
# 4                    100            3.00

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import time

print('importações selenium ok')
# Out:
# importações selenium ok

# %%
#teste
#abre o navegador
web = webdriver.Chrome()

#abre a página
web.get('http://127.0.0.1:5500/index.html')

#espera a pagina carregar
time.sleep(5)

#selecionar input com atributo name=codigo
codigo = web.find_element(By.NAME, 'codigo')
codigo.clear()
codigo.send_keys('codigo')

descricao = web.find_element(By.NAME, 'descricao')
descricao.clear()
descricao.send_keys('descricao')

p_compra = web.find_element(By.NAME, 'p_compra')
p_compra.clear()
p_compra.send_keys('1.00')

estoque = web.find_element(By.NAME, 'estoque')
estoque.clear()
estoque.send_keys('10')

p_venda = web.find_element(By.NAME, 'p_venda')
p_venda.clear()
p_venda.send_keys('2.00')


btn_click = web.find_element(By.ID, 'cadastrar')
btn_click.click()

time.sleep(3)

web.quit() #fecha o navegador

# %%
produtos.columns
# Out:
# Index(['Código do Produto', 'Descrição', 'Preço de Compra',
#        'Quantidade em Estoque', 'Preço de Venda'],
#       dtype='object')

# %%
#renomeando colunas para facilitar o preenchimento
produtos = produtos.rename(columns={
    'Código do Produto': 'codigo',
    'Descrição': 'descricao',
    'Preço de Compra': 'p_compra',
    'Quantidade em Estoque': 'estoque',
    'Preço de Venda': 'p_venda' 
})
produtos.head()
# Out:
#     codigo                    descricao  p_compra  estoque  p_venda
# 0  PROD001    Caneta Esferográfica Azul       0.5      150     1.20
# 1  PROD002  Caderno Universitário 96fls       8.0       75    15.00
# 2  PROD003               Lápis Preto HB       0.3      200     0.80
# 3  PROD004              Borracha Branca       0.4      180     0.95
# 4  PROD005       Apontador com Depósito       1.5      100     3.00

# %%
#completando todos os códigos

#abre o navegador
web = webdriver.Chrome()

#abre a página
web.get('http://127.0.0.1:5500/index.html')

#espera a pagina carregar
time.sleep(5)

for _, produto in produtos.iterrows():
    codigo = web.find_element(By.NAME, 'codigo')
    codigo.clear()
    codigo.send_keys(str(produto['codigo']))

    descricao = web.find_element(By.NAME, 'descricao')
    descricao.clear()
    descricao.send_keys(str(produto['descricao']))

    p_compra = web.find_element(By.NAME, 'p_compra')
    p_compra.clear()
    p_compra.send_keys(str(produto['p_compra']))

    estoque = web.find_element(By.NAME, 'estoque')
    estoque.clear()
    estoque.send_keys(str(produto['estoque']))

    p_venda = web.find_element(By.NAME, 'p_venda')
    p_venda.clear()
    p_venda.send_keys(str(produto['p_venda']))

    btn_click = web.find_element(By.ID, 'cadastrar')
    btn_click.click()

    time.sleep(2)


web.quit() #fecha o navegador
